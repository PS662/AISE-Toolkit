# %%
from ibm_watson import SpeechToTextV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
import json
import glob
import os

# %%
authenticator = IAMAuthenticator('aRUa2wvF6NEWP0lQjcu8YEi0QbZa-B2Km-2OP9p2oqlE') #replace {APIkey} by your API key
speech_to_text = SpeechToTextV1(
authenticator=authenticator
)
speech_to_text.set_service_url('https://api.au-syd.speech-to-text.watson.cloud.ibm.com/instances/cdd27c84-7f44-4e34-8a1d-7aa0e1f46c0c') #replace {url} by your URL

# %%
with open('SpeechtoTextData/arctic_a0005.wav', 'rb') as audio_file:
    speech_recognition_results = speech_to_text.recognize(
        audio = audio_file,
        content_type='audio/wav').get_result()
print(json.dumps(speech_recognition_results, indent = 2))
# Out:
# {
#   "result_index": 0,
#   "results": [
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "will we ever forget it ",
#           "confidence": 0.95
#         }
#       ]
#     }
#   ]
# }

# %%
with open('SpeechtoTextData/arctic_a0005.json', 'w') as outfile:
    json.dump(speech_recognition_results, outfile)

# %%
with open('SpeechtoTextData/arctic_a0005.json') as infile:
    data = json.load(infile) # load data from a json file
print(data)
# Out:
# {'result_index': 0, 'results': [{'final': True, 'alternatives': [{'transcript': 'will we ever forget it ', 'confidence': 0.95}]}]}

# %%
files = glob.glob("SpeechtoTextData/*")
for file in files:
    filename, file_extension = os.path.splitext(file)
    print("Processing: ", filename, file_extension)
    if file_extension == ".wav" or file_extension == ".flac":
        audio_file = open(file, 'rb')
        speech_recognition_results = speech_to_text.recognize(
            audio = audio_file,
            content_type='audio/'+file_extension[1:]).get_result()
        print(json.dumps(speech_recognition_results, indent = 2))
    else:
        print("Unsupported extension")
# Out:
# Processing:  SpeechtoTextData\367-130732-0000 .flac
# {
#   "result_index": 0,
#   "results": [
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "lobsters and law officers ",
#           "confidence": 0.74
#         }
#       ]
#     }
#   ]
# }
# Processing:  SpeechtoTextData\367-130732-0001 .flac
# {
#   "result_index": 0,
#   "results": [
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "when is a lobster not a lobster when it is a crayfish ",
#           "confidence": 0.87
#         }
#       ]
#     }
#   ]
# }
# Processing:  SpeechtoTextData\367-130732-0004 .flac
# {
#   "result_index": 0,
#   "results": [
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "a book could be written about this restaurant and then all would not be told for all its secrets can never be known ",
#           "confidence": 0.92
#         }
#       ]
#     }
#   ]
# }
# ...
